# %%
import matplotlib.pyplot as plt
x = [28.329892596754373,153.09848552593982,184.06711304099045,247.47854077121318,90.14265529313519]
y = ["PHARMA",'FMCG','IT','METAL','AUTO']
plt.bar(y,x)
plt.show()
